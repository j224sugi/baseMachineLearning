# %%
import pandas as pd
import os

fileNames=["LongMethod.csv","FeatureEnvy.csv"]
folder="C:\\Users\\syuuj\\machinelearning\\dataset"
saveFolder="C:\\Users\\syuuj\\machinelearning\\dataset2"
if not os.path.isdir(saveFolder):
    os.makedirs(saveFolder)
for fileName in fileNames:
    df=pd.read_csv(os.path.join(folder,fileName),encoding_errors="replace")
    oldMetrics=['fanin_y', 'fanout_y', 'wmc_y', 'loc_y', 'returnsQty_y', 'variablesQty_y', 'parametersQty_y', 'loopQty_y', 'anonymousClassesQty_y', 'innerClassesQty_y', 'ATFD_y', 'ATLD_y', 'LAA_y', 'FDP_y', 'line_y']
    df[oldMetrics]=df[oldMetrics].fillna(0)
    df.to_csv(os.path.join(saveFolder,fileName),index=False)

# %%
fileNames=["GodClass.csv","RefusedBequest.csv"]
folder="C:\\Users\\syuuj\\machinelearning\\dataset"
saveFolder="C:\\Users\\syuuj\\machinelearning\\dataset2"
if not os.path.isdir(saveFolder):
    os.makedirs(saveFolder)
for fileName in fileNames:
    df=pd.read_csv(os.path.join(folder,fileName),encoding_errors="replace")
    oldMetrics=['dit_y', 'fanin_y', 'fanout_y', 'lcc_y', 'lcom*_y', 'loc_y', 'noc_y', 'rfc_y', 'innerClassesQty_y', 'totalFieldsQty_y', 'totalMethodsQty_y', 'wmc_y', 'tcc_y', 'NprotM_y', 'BOvR_y', 'ATFD_y', 'ATLD_y', 'LAA_y', 'BUR_y', 'FDP_y','line_y']
    df[oldMetrics]=df[oldMetrics].fillna(0)
    df.to_csv(os.path.join(saveFolder,fileName),index=False)

# %%
code="dit_y	fanin_y	fanout_y	lcc_y	lcom*_y	loc_y	noc_y	rfc_y	innerClassesQty_y	totalFieldsQty_y	totalMethodsQty_y	wmc_y	tcc_y	NprotM_y	BOvR_y	ATFD_y	ATLD_y	LAA_y	BUR_y	FDP_y"
print(code.split("\t"))
# Out:
# ['dit_y', 'fanin_y', 'fanout_y', 'lcc_y', 'lcom*_y', 'loc_y', 'noc_y', 'rfc_y', 'innerClassesQty_y', 'totalFieldsQty_y', 'totalMethodsQty_y', 'wmc_y', 'tcc_y', 'NprotM_y', 'BOvR_y', 'ATFD_y', 'ATLD_y', 'LAA_y', 'BUR_y', 'FDP_y']
