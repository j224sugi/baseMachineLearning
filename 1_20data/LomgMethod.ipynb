# %%
a="""base :  {'f1': [0.16498625114573787, 0.3153724247226624, 0.3380281690140845, 0.3391915641476274, 0.3874873864783047, 0.4051172707889126, 0.4471445929526124, 0.4575, 0.45848822800495664, 0.4621212121212121], 'auc': [0.9065662743757018, 0.9595488968204777, 0.9441791874158457, 0.9465176790757338, 0.9454734835865142, 0.9412338831106188, 0.9281223297414887, 0.9259712878718352, 0.9306214926501494, 0.9260426973157341], 'feature': [array(['variablesQty_x'], dtype=object), array(['loc_x', 'variablesQty_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x loopQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x loopQty_x'], dtype=object)]}
add :  {'f1': [0.16498625114573787, 0.3153724247226624, 0.43058823529411766, 0.5085714285714286, 0.5128205128205128, 0.5041095890410959, 0.5149359886201992, 0.5468277945619335, 0.5435114503816794, 0.5457317073170732], 'auc': [0.9065662743757018, 0.9595488968204777, 0.9255249788474667, 0.9150821858162573, 0.9197770214970085, 0.928952464526814, 0.9221244393373841, 0.9224904127373661, 0.9154838639381889, 0.9178312817785644], 'feature': [array(['variablesQty_x'], dtype=object), array(['loc_x', 'variablesQty_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD_x LAA_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x', 'ATFD_x LAA_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x ATFD_x', 'ATFD_x LAA_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x ATFD_x', 'ATFD_x LAA_x', 'LAA_x^2'], dtype=object)]}"""
print(a.replace("array","np.array"))
# Out:
# base :  {'f1': [0.16498625114573787, 0.3153724247226624, 0.3380281690140845, 0.3391915641476274, 0.3874873864783047, 0.4051172707889126, 0.4471445929526124, 0.4575, 0.45848822800495664, 0.4621212121212121], 'auc': [0.9065662743757018, 0.9595488968204777, 0.9441791874158457, 0.9465176790757338, 0.9454734835865142, 0.9412338831106188, 0.9281223297414887, 0.9259712878718352, 0.9306214926501494, 0.9260426973157341], 'feature': [np.array(['variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
#        'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
#        'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
#        'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

base =  {'f1': [0.16498625114573787, 0.3153724247226624, 0.3380281690140845, 0.3391915641476274, 0.3874873864783047, 0.4051172707889126, 0.4471445929526124, 0.4575, 0.45848822800495664, 0.4621212121212121], 'auc': [0.9065662743757018, 0.9595488968204777, 0.9441791874158457, 0.9465176790757338, 0.9454734835865142, 0.9412338831106188, 0.9281223297414887, 0.9259712878718352, 0.9306214926501494, 0.9260426973157341], 'feature': [np.array(['variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x loopQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x loopQty_x'], dtype=object)]}
add =  {'f1': [0.16498625114573787, 0.3153724247226624, 0.43058823529411766, 0.5085714285714286, 0.5128205128205128, 0.5041095890410959, 0.5149359886201992, 0.5468277945619335, 0.5435114503816794, 0.5457317073170732], 'auc': [0.9065662743757018, 0.9595488968204777, 0.9255249788474667, 0.9150821858162573, 0.9197770214970085, 0.928952464526814, 0.9221244393373841, 0.9224904127373661, 0.9154838639381889, 0.9178312817785644], 'feature': [np.array(['variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD_x LAA_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x', 'ATFD_x LAA_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'ATFD_x LAA_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x ATFD_x', 'ATFD_x LAA_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'ATFD_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x',
       'parametersQty_x ATFD_x', 'ATFD_x LAA_x', 'LAA_x^2'], dtype=object)]}

# %%
factors=["f1","auc","feature"]
for factor in factors:
    print(factor)
    print(base[factor][4])
    print(add[factor][4])
# Out:
# f1
# 0.3874873864783047
# 0.5128205128205128
# auc
# 0.9454734835865142
# 0.9197770214970085
# feature
# ['wmc_x' 'loc_x' 'variablesQty_x' 'loc_x parametersQty_x'
#  'variablesQty_x parametersQty_x']
# ['loc_x' 'variablesQty_x' 'ATFD_x' 'loc_x parametersQty_x' 'ATFD_x LAA_x']

# %%
x=np.arange(1,11,1)

plt.title("F1")
plt.ylim(-0.05,1.0)
plt.plot(x,add["f1"],label="add",marker=".")
plt.legend()
plt.show()

plt.title("AUC")
plt.ylim(0.45,1.0)
plt.plot(x,add["auc"],label="add",marker=".")
plt.legend()
plt.show()
