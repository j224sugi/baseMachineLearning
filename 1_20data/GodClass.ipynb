# %%
a="""base :  {'f1': [0.4737516005121639, 0.5250379362670713, 0.5714285714285714, 0.6872852233676976, 0.6781411359724613, 0.6832740213523132, 0.6782608695652174, 0.7164685908319185, 0.715008431703204, 0.7125220458553791], 'auc': [0.8755180273518441, 0.858224547589446, 0.8884557604641525, 0.9259652576322697, 0.919222268269098, 0.9094056499516506, 0.9151643873463186, 0.950416148639315, 0.9523630681033293, 0.9317455794999309], 'feature': [array(['rfc_x'], dtype=object), array(['rfc_x', 'lcom*_x rfc_x'], dtype=object), array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x'], dtype=object), array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x'],
      dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x',
       'lcom*_x wmc_x'], dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x wmc_x'], dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'],
      dtype=object), array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'],
      dtype=object), array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x loc_x', 'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x',
       'lcom*_x wmc_x'], dtype=object), array(['fanout_x', 'lcom*_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x',
       'lcom*_x^2', 'lcom*_x loc_x', 'lcom*_x rfc_x',
       'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'], dtype=object)]}
add :  {'f1': [0.4737516005121639, 0.5250379362670713, 0.5714285714285714, 0.6872852233676976, 0.6921739130434783, 0.6632124352331606, 0.6948529411764706, 0.671304347826087, 0.7147766323024055, 0.7256944444444444], 'auc': [0.8755180273518441, 0.858224547589446, 0.8884557604641525, 0.9259652576322697, 0.9242644011603812, 0.9080112929962703, 0.9040570175438597, 0.9106143804392872, 0.944165285260395, 0.9469324146981626], 'feature': [array(['rfc_x'], dtype=object), array(['rfc_x', 'lcom*_x rfc_x'], dtype=object), array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x'], dtype=object), array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x'],
      dtype=object), array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x',
       'lcom*_x wmc_x', 'rfc_x LAA_x'], dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x wmc_x', 'rfc_x LAA_x'], dtype=object), array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'lcom*_x ATFD_x', 'rfc_x LAA_x'], dtype=object)]}"""
print(a.replace("array","np.array"))
# Out:
# base :  {'f1': [0.4737516005121639, 0.5250379362670713, 0.5714285714285714, 0.6872852233676976, 0.6781411359724613, 0.6832740213523132, 0.6782608695652174, 0.7164685908319185, 0.715008431703204, 0.7125220458553791], 'auc': [0.8755180273518441, 0.858224547589446, 0.8884557604641525, 0.9259652576322697, 0.919222268269098, 0.9094056499516506, 0.9151643873463186, 0.950416148639315, 0.9523630681033293, 0.9317455794999309], 'feature': [np.array(['rfc_x'], dtype=object), np.array(['rfc_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x'],
#       dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x',
#        'lcom*_x wmc_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
#        'lcom*_x rfc_x', 'lcom*_x wmc_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

base =  {'f1': [0.4737516005121639, 0.5250379362670713, 0.5714285714285714, 0.6872852233676976, 0.6781411359724613, 0.6832740213523132, 0.6782608695652174, 0.7164685908319185, 0.715008431703204, 0.7125220458553791], 'auc': [0.8755180273518441, 0.858224547589446, 0.8884557604641525, 0.9259652576322697, 0.919222268269098, 0.9094056499516506, 0.9151643873463186, 0.950416148639315, 0.9523630681033293, 0.9317455794999309], 'feature': [np.array(['rfc_x'], dtype=object), np.array(['rfc_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x'],
      dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x',
       'lcom*_x wmc_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x wmc_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'],
      dtype=object), np.array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'],
      dtype=object), np.array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x loc_x', 'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x',
       'lcom*_x wmc_x'], dtype=object), np.array(['fanout_x', 'lcom*_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x',
       'lcom*_x^2', 'lcom*_x loc_x', 'lcom*_x rfc_x',
       'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x'], dtype=object)]}
add =  {'f1': [0.4737516005121639, 0.5250379362670713, 0.5714285714285714, 0.6872852233676976, 0.6921739130434783, 0.6632124352331606, 0.6948529411764706, 0.671304347826087, 0.7147766323024055, 0.7256944444444444], 'auc': [0.8755180273518441, 0.858224547589446, 0.8884557604641525, 0.9259652576322697, 0.9242644011603812, 0.9080112929962703, 0.9040570175438597, 0.9106143804392872, 0.944165285260395, 0.9469324146981626], 'feature': [np.array(['rfc_x'], dtype=object), np.array(['rfc_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x'], dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x'],
      dtype=object), np.array(['rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x rfc_x',
       'lcom*_x wmc_x', 'rfc_x LAA_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x wmc_x', 'rfc_x LAA_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'rfc_x LAA_x'], dtype=object), np.array(['fanout_x', 'rfc_x', 'wmc_x', 'fanout_x lcom*_x', 'lcom*_x^2',
       'lcom*_x rfc_x', 'lcom*_x totalMethodsQty_x', 'lcom*_x wmc_x',
       'lcom*_x ATFD_x', 'rfc_x LAA_x'], dtype=object)]}

# %%
factors=["f1","auc","feature"]
for factor in factors:
    print(factor)
    print(base[factor][4])
    print(add[factor][4])
# Out:
# f1
# 0.6781411359724613
# 0.6921739130434783
# auc
# 0.919222268269098
# 0.9242644011603812
# feature
# ['fanout_x' 'rfc_x' 'fanout_x lcom*_x' 'lcom*_x rfc_x' 'lcom*_x wmc_x']
# ['rfc_x' 'fanout_x lcom*_x' 'lcom*_x rfc_x' 'lcom*_x wmc_x' 'rfc_x LAA_x']

# %%
x=np.arange(1,11,1)

plt.title("GodClass_F1")
plt.ylim(0,1.0)
plt.plot(x,add["f1"],label="add",marker=".")
plt.legend()
plt.show()

plt.title("GodClass_AUC")
plt.ylim(0.5,1.0)
plt.plot(x,add["auc"],label="add",marker=".")
plt.legend()
plt.show()

# %%
x=np.arange(1,11,1)

plt.title("GodClass_F1")
plt.ylim(0,1.0)
plt.plot(x,add["f1"],label="add",marker=".")
plt.legend()
plt.show()

plt.title("GodClass_AUC")
plt.ylim(0.5,1.0)
plt.plot(x,add["auc"],label="add",marker=".")
plt.legend()
plt.show()
