# %%
a="""base :  {'f1': [0.12132204756146715, 0.12241735537190082, 0.15076414704667493, 0.15711727842435094, 0.15736505032021958, 0.16001823569637566, 0.17086280056577086, 0.1756070016939582, 0.1848879047882646, 0.184460592509782], 'auc': [0.657001079596401, 0.6254373322447802, 0.6994767380655458, 0.6937946856471467, 0.6901330115770425, 0.6945251524244356, 0.6705166934387924, 0.6762745255738829, 0.6905100237194655, 0.6882385646705114], 'feature': [array(['loc_x'], dtype=object), array(['loc_x', 'variablesQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x^2',
       'variablesQty_x parametersQty_x'], dtype=object)]}
add :  {'f1': [0.016965127238454288, 0.1886234917508003, 0.19095477386934673, 0.2065063649222065, 0.2225475841874085, 0.22784810126582278, 0.23403263403263402, 0.2827167310877968, 0.2891566265060241, 0.30831878999418266], 'auc': [0.5033229428774612, 0.718161798483191, 0.6539874210271369, 0.629586122198681, 0.6360563848943372, 0.6450004619479998, 0.65006643033088, 0.6563123445756631, 0.6613512586334584, 0.6629629694385509], 'feature': [array(['LAA_x^2'], dtype=object), array(['ATFD_x', 'LAA_x^2'], dtype=object), array(['loc_x', 'ATFD_x', 'LAA_x^2'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'LAA_x^2'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD', 'LAA_x^2'],
      dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object), array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc', 'ATFD', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc', 'ATFD',
       'ATFD_x LAA_x', 'LAA_x^2'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc',
       'variablesQty', 'ATFD', 'ATFD_x LAA_x', 'LAA_x^2'], dtype=object), array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc',
       'variablesQty', 'ATFD', 'parametersQty_x ATFD_x', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object)]}"""
print(a.replace("array","np.array"))
# Out:
# base :  {'f1': [0.12132204756146715, 0.12241735537190082, 0.15076414704667493, 0.15711727842435094, 0.15736505032021958, 0.16001823569637566, 0.17086280056577086, 0.1756070016939582, 0.1848879047882646, 0.184460592509782], 'auc': [0.657001079596401, 0.6254373322447802, 0.6994767380655458, 0.6937946856471467, 0.6901330115770425, 0.6945251524244356, 0.6705166934387924, 0.6762745255738829, 0.6905100237194655, 0.6882385646705114], 'feature': [np.array(['loc_x'], dtype=object), np.array(['loc_x', 'variablesQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x'],
#       dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
#        'loc_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
#        'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

base =  {'f1': [0.12132204756146715, 0.12241735537190082, 0.15076414704667493, 0.15711727842435094, 0.15736505032021958, 0.16001823569637566, 0.17086280056577086, 0.1756070016939582, 0.1848879047882646, 0.184460592509782], 'auc': [0.657001079596401, 0.6254373322447802, 0.6994767380655458, 0.6937946856471467, 0.6901330115770425, 0.6945251524244356, 0.6705166934387924, 0.6762745255738829, 0.6905100237194655, 0.6882385646705114], 'feature': [np.array(['loc_x'], dtype=object), np.array(['loc_x', 'variablesQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loc_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'loc_x parametersQty_x',
       'variablesQty_x parametersQty_x'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x parametersQty_x'],
      dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'loopQty_x', 'fanout_x loc_x',
       'fanout_x variablesQty_x', 'wmc_x parametersQty_x',
       'loc_x parametersQty_x', 'variablesQty_x^2',
       'variablesQty_x parametersQty_x'], dtype=object)]}
add = {'f1': [0.016965127238454288, 0.1886234917508003, 0.19095477386934673, 0.2065063649222065, 0.2225475841874085, 0.22784810126582278, 0.23403263403263402, 0.2827167310877968, 0.2891566265060241, 0.30831878999418266], 'auc': [0.5033229428774612, 0.718161798483191, 0.6539874210271369, 0.629586122198681, 0.6360563848943372, 0.6450004619479998, 0.65006643033088, 0.6563123445756631, 0.6613512586334584, 0.6629629694385509], 'feature': [np.array(['LAA_x^2'], dtype=object), np.array(['ATFD_x', 'LAA_x^2'], dtype=object), np.array(['loc_x', 'ATFD_x', 'LAA_x^2'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'LAA_x^2'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD', 'LAA_x^2'],
      dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'ATFD', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object), np.array(['loc_x', 'variablesQty_x', 'ATFD_x', 'loc', 'ATFD', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc', 'ATFD',
       'ATFD_x LAA_x', 'LAA_x^2'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc',
       'variablesQty', 'ATFD', 'ATFD_x LAA_x', 'LAA_x^2'], dtype=object), np.array(['wmc_x', 'loc_x', 'variablesQty_x', 'ATFD_x', 'loc',
       'variablesQty', 'ATFD', 'parametersQty_x ATFD_x', 'ATFD_x LAA_x',
       'LAA_x^2'], dtype=object)]}

# %%
factors=["f1","auc","feature"]
for factor in factors:
    print(factor)
    print(base[factor][4])
    print(add[factor][4])
# Out:
# f1
# 0.15736505032021958
# 0.2225475841874085
# auc
# 0.6901330115770425
# 0.6360563848943372
# feature
# ['wmc_x' 'loc_x' 'variablesQty_x' 'loopQty_x' 'loc_x parametersQty_x']
# ['loc_x' 'variablesQty_x' 'ATFD_x' 'ATFD' 'LAA_x^2']

# %%
x=np.arange(1,11,1)

plt.title("F1")
plt.ylim(-0.05,1.0)
plt.plot(x,add["f1"],label="add",marker=".")
plt.legend()
plt.show()

plt.title("AUC")
plt.ylim(0.45,1.0)
plt.plot(x,add["auc"],label="add",marker=".")
plt.legend()
plt.show()
