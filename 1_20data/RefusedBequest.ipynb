# %%
a="""base :  {'f1': [0.08536585365853659, 0.07444168734491315, 0.10606060606060606, 0.08983451536643026, 0.12709030100334448, 0.134185303514377, 0.10752688172043011, 0.09933774834437085, 0.09859154929577464, 0.1318051575931232], 'auc': [0.5672465614914747, 0.6358055043838386, 0.6359267005554248, 0.6780094740778704, 0.6878852306882558, 0.7086686427413882, 0.6456812609942242, 0.6438494674293946, 0.6343338365860077, 0.7276999044281619], 'feature': [array(['dit_x'], dtype=object), array(['dit_x', 'rfc_x'], dtype=object), array(['dit_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x',
       'lcc_x totalMethodsQty_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'lcc_x rfc_x',
       'lcc_x totalMethodsQty_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'lcc_x rfc_x', 'lcc_x totalMethodsQty_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'lcc_x rfc_x', 'lcc_x totalMethodsQty_x', 'lcom*_x rfc_x'],
      dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'fanout_x lcom*_x', 'lcc_x rfc_x', 'lcc_x totalMethodsQty_x',
       'lcom*_x rfc_x'], dtype=object), array(['dit_x', 'fanout_x', 'rfc_x', 'wmc_x', 'dit_x lcc_x',
       'dit_x lcom*_x', 'fanout_x lcom*_x', 'lcc_x rfc_x',
       'lcc_x totalMethodsQty_x', 'lcom*_x rfc_x'], dtype=object)]}
add :  {'f1': [0.18250950570342206, 0.200836820083682, 0.17117117117117117, 0.19011406844106463, 0.19014084507042253, 0.20149253731343283, 0.22393822393822393, 0.22624434389140272, 0.2134387351778656, 0.25112107623318386], 'auc': [0.7454984279125172, 0.7474098646758176, 0.6940177569705113, 0.7564476363283793, 0.7766735459922157, 0.7779478371677493, 0.8005630427857114, 0.759792650664155, 0.7791424851448121, 0.7924809895147997], 'feature': [array(['BOvR_x^2'], dtype=object), array(['BOvR_x', 'BOvR_x^2'], dtype=object), array(['BOvR_x', 'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), array(['BOvR_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), array(['BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x'],
      dtype=object), array(['dit_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x', 'BOvR_x^2',
       'BOvR_x BUR_x'], dtype=object), array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x',
       'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x',
       'BOvR_x^2', 'BOvR_x BUR_x', 'BUR_x^2'], dtype=object), array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'lcom*_x BOvR_x',
       'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x', 'BUR_x^2'], dtype=object), array(['dit_x', 'rfc_x', 'BOvR_x', 'BUR_x', 'dit_x LAA_x',
       'lcom*_x BOvR_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x',
       'BUR_x^2'], dtype=object)]}"""
print(a.replace("array","np.array"))
# Out:
# base :  {'f1': [0.08536585365853659, 0.07444168734491315, 0.10606060606060606, 0.08983451536643026, 0.12709030100334448, 0.134185303514377, 0.10752688172043011, 0.09933774834437085, 0.09859154929577464, 0.1318051575931232], 'auc': [0.5672465614914747, 0.6358055043838386, 0.6359267005554248, 0.6780094740778704, 0.6878852306882558, 0.7086686427413882, 0.6456812609942242, 0.6438494674293946, 0.6343338365860077, 0.7276999044281619], 'feature': [np.array(['dit_x'], dtype=object), np.array(['dit_x', 'rfc_x'], dtype=object), np.array(['dit_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x',
#        'lcc_x totalMethodsQty_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'lcc_x rfc_x',
#        'lcc_x totalMethodsQty_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

base =  {'f1': [0.08536585365853659, 0.07444168734491315, 0.10606060606060606, 0.08983451536643026, 0.12709030100334448, 0.134185303514377, 0.10752688172043011, 0.09933774834437085, 0.09859154929577464, 0.1318051575931232], 'auc': [0.5672465614914747, 0.6358055043838386, 0.6359267005554248, 0.6780094740778704, 0.6878852306882558, 0.7086686427413882, 0.6456812609942242, 0.6438494674293946, 0.6343338365860077, 0.7276999044281619], 'feature': [np.array(['dit_x'], dtype=object), np.array(['dit_x', 'rfc_x'], dtype=object), np.array(['dit_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x',
       'lcc_x totalMethodsQty_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'lcc_x rfc_x',
       'lcc_x totalMethodsQty_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'lcc_x rfc_x', 'lcc_x totalMethodsQty_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'lcc_x rfc_x', 'lcc_x totalMethodsQty_x', 'lcom*_x rfc_x'],
      dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'dit_x lcc_x', 'dit_x lcom*_x',
       'fanout_x lcom*_x', 'lcc_x rfc_x', 'lcc_x totalMethodsQty_x',
       'lcom*_x rfc_x'], dtype=object), np.array(['dit_x', 'fanout_x', 'rfc_x', 'wmc_x', 'dit_x lcc_x',
       'dit_x lcom*_x', 'fanout_x lcom*_x', 'lcc_x rfc_x',
       'lcc_x totalMethodsQty_x', 'lcom*_x rfc_x'], dtype=object)]}
add = {'f1': [0.18250950570342206, 0.200836820083682, 0.17117117117117117, 0.19011406844106463, 0.19014084507042253, 0.20149253731343283, 0.22393822393822393, 0.22624434389140272, 0.2134387351778656, 0.25112107623318386], 'auc': [0.7454984279125172, 0.7474098646758176, 0.6940177569705113, 0.7564476363283793, 0.7766735459922157, 0.7779478371677493, 0.8005630427857114, 0.759792650664155, 0.7791424851448121, 0.7924809895147997], 'feature': [np.array(['BOvR_x^2'], dtype=object), np.array(['BOvR_x', 'BOvR_x^2'], dtype=object), np.array(['BOvR_x', 'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), np.array(['BOvR_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), np.array(['BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x'],
      dtype=object), np.array(['dit_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x', 'BOvR_x^2',
       'BOvR_x BUR_x'], dtype=object), np.array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x',
       'BOvR_x^2', 'BOvR_x BUR_x'], dtype=object), np.array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'rfc_x LAA_x',
       'BOvR_x^2', 'BOvR_x BUR_x', 'BUR_x^2'], dtype=object), np.array(['dit_x', 'rfc_x', 'BOvR_x', 'dit_x LAA_x', 'lcom*_x BOvR_x',
       'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x', 'BUR_x^2'], dtype=object), np.array(['dit_x', 'rfc_x', 'BOvR_x', 'BUR_x', 'dit_x LAA_x',
       'lcom*_x BOvR_x', 'rfc_x LAA_x', 'BOvR_x^2', 'BOvR_x BUR_x',
       'BUR_x^2'], dtype=object)]}

# %%
factors=["f1","auc","feature"]
for factor in factors:
    print(factor)
    print(base[factor][4])
    print(add[factor][4])
# Out:
# f1
# 0.12709030100334448
# 0.19014084507042253
# auc
# 0.6878852306882558
# 0.7766735459922157
# feature
# ['dit_x' 'fanout_x' 'rfc_x' 'dit_x lcc_x' 'lcc_x totalMethodsQty_x']
# ['BOvR_x' 'dit_x LAA_x' 'rfc_x LAA_x' 'BOvR_x^2' 'BOvR_x BUR_x']

# %%
x=np.arange(1,11,1)

plt.title("F1")
plt.ylim(-0.05,1.0)
plt.plot(x,add["f1"],label="add",marker=".")
plt.legend()
plt.show()

plt.title("AUC")
plt.ylim(0.45,1.0)
plt.plot(x,add["auc"],label="add",marker=".")
plt.legend()
plt.show()
